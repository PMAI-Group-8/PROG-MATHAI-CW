# %%
import torch
print(torch.xpu.is_available())  # torch.xpu is the API for Intel GPU support
# Out:
# False

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/xpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/xpu
# Requirement already satisfied: torch in c:\users\vxv19\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: torchvision in c:\users\vxv19\anaconda3\lib\site-packages (0.24.1)
# Requirement already satisfied: torchaudio in c:\users\vxv19\anaconda3\lib\site-packages (2.9.1+xpu)
# Requirement already satisfied: filelock in c:\users\vxv19\anaconda3\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\vxv19\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\vxv19\anaconda3\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\vxv19\anaconda3\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\vxv19\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\vxv19\anaconda3\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\vxv19\anaconda3\lib\site-packages (from torch) (72.1.0)
# Requirement already satisfied: numpy in c:\users\vxv19\anaconda3\lib\site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\vxv19\anaconda3\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\vxv19\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vxv19\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
