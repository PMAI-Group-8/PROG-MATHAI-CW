# %%
from Cifar10Loader import Cifar10Loader
from neural_network import NeuralNetwork
from neuron_layer import NeuronLayer

import numpy as np
np.random.seed(42)

# %%
loader = Cifar10Loader("data/cifar-10-batches-py")

X_train, y_train = loader.load_train_data()
X_test, y_test = loader.load_test_data()

# Preprocess
X_train = X_train / 255.0          # normalise
y_train = one_hot(y_train, 10)     # one-hot

# Train
nn.train(X_train, y_train)
